# %%
import torch 
import torch.nn.functional as F

# %%
target = torch.FloatTensor([[.1, .2, .3],
                             [.4, .5, .6],
                             [.7, .8, .9]])

# %%
x = torch.rand_like(target) # 0 ~ 1 범위에서 랜덤값으로 target 과 같은 shape의 텐서를 생성
x.requires_grad = True      # x 를 미분 가능한 텐서로 설정하여. backward() 호출 시 x에 대한 기울기 자동 계산 

x
# Out:
# tensor([[0.2915, 0.6547, 0.0097],
#         [0.0255, 0.4657, 0.1507],
#         [0.0211, 0.1772, 0.6772]], requires_grad=True)

# %%
loss = F.mse_loss(x,target)     # x와 target간의 평균제고옵차(MSE) 계산 (X는 예측값, target은 정답값으로 가정)
loss
# Out:
# tensor(0.1744, grad_fn=<MseLossBackward0>)

# %%
threshold = 1e-5                                # 손실함수 종료 기준값
learning_rate = 1.                              # 가중치 업데이트 사용할 학습률
iter_cnt = 0                                    # 반복 횟수 카운터 초기화

while loss > threshold:                         # 손실이 임계값보다 클 동안 반복
    iter_cnt += 1                               # 반복 횟수 증가
    
    loss.backward()                             # loss에 대한 역전파 수행(loss)
    
    x = x - learning_rate * x.grad              # gradient descent 방식으로 x를 업데이트
    
    x.detach_()                                 # 기존 계산그래프에서 x 분리
    x.requires_grad_(True)                      # 다음 반복을 위해 gradient 추적 다시 활성화
    
    loss = F.mse_loss(x, target)                # 업데이트 x로 새로운 손실 계산
    
    print(f"{iter_cnt}번째 : Loss : {loss}")    # 현재 반복의 손실 값 출력
    print(x)
# Out:
# 1번째 : Loss : 0.10548523813486099
# tensor([[0.2490, 0.5536, 0.0742],
#         [0.1087, 0.4734, 0.2505],
#         [0.1720, 0.3156, 0.7267]], requires_grad=True)
# 2번째 : Loss : 0.06381206214427948
# tensor([[0.2159, 0.4750, 0.1244],
#         [0.1734, 0.4793, 0.3282],
#         [0.2893, 0.4233, 0.7652]], requires_grad=True)
# 3번째 : Loss : 0.03860235586762428
# tensor([[0.1901, 0.4139, 0.1634],
#         [0.2238, 0.4839, 0.3886],
#         [0.3806, 0.5070, 0.7952]], requires_grad=True)
# 4번째 : Loss : 0.023352041840553284
# tensor([[0.1701, 0.3664, 0.1938],
#         [0.2629, 0.4875, 0.4356],
#         [0.4516, 0.5721, 0.8185]], requires_grad=True)
# 5번째 : Loss : 0.014126542955636978
# tensor([[0.1545, 0.3294, 0.2174],
#         [0.2934, 0.4902, 0.4721],
#         [0.5068, 0.6227, 0.8366]], requires_grad=True)
# 6번째 : Loss : 0.008545687422156334
# tensor([[0.1424, 0.3007, 0.2357],
#         [0.3171, 0.4924, 0.5005],
#         [0.5497, 0.6621, 0.8507]], requires_grad=True)
# 7번째 : Loss : 0.005169613752514124
# tensor([[0.1330, 0.2783, 0.2500],
#         [0.3355, 0.4941, 0.5226],
#         [0.5831, 0.6928, 0.8616]], requires_grad=True)
# 8번째 : Loss : 0.003127296455204487
# tensor([[0.1256, 0.2609, 0.2611],
#         [0.3498, 0.4954, 0.5398],
#         [0.6091, 0.7166, 0.8702]], requires_grad=True)
# 9번째 : Loss : 0.001891820807941258
# tensor([[0.1199, 0.2474, 0.2698],
#         [0.3610, 0.4964, 0.5532],
#         [0.6293, 0.7351, 0.8768]], requires_grad=True)
# 10번째 : Loss : 0.001144434791058302
# tensor([[0.1155, 0.2368, 0.2765],
#         [0.3697, 0.4972, 0.5636],
#         [0.6450, 0.7495, 0.8820]], requires_grad=True)
# 11번째 : Loss : 0.0006923126056790352
# tensor([[0.1121, 0.2286, 0.2817],
#         [0.3764, 0.4978, 0.5717],
#         [0.6572, 0.7608, 0.8860]], requires_grad=True)
# 12번째 : Loss : 0.0004188063903711736
# tensor([[0.1094, 0.2223, 0.2858],
#         [0.3816, 0.4983, 0.5780],
#         [0.6667, 0.7695, 0.8891]], requires_grad=True)
# 13번째 : Loss : 0.0002533519873395562
# tensor([[0.1073, 0.2173, 0.2889],
#         [0.3857, 0.4987, 0.5829],
#         [0.6741, 0.7763, 0.8915]], requires_grad=True)
# 14번째 : Loss : 0.00015326234279200435
# tensor([[0.1057, 0.2135, 0.2914],
#         [0.3889, 0.4990, 0.5867],
#         [0.6799, 0.7815, 0.8934]], requires_grad=True)
# 15번째 : Loss : 9.271413728129119e-05
# tensor([[0.1044, 0.2105, 0.2933],
#         [0.3914, 0.4992, 0.5896],
#         [0.6843, 0.7856, 0.8949]], requires_grad=True)
# 16번째 : Loss : 5.608643186860718e-05
# tensor([[0.1034, 0.2082, 0.2948],
#         [0.3933, 0.4994, 0.5919],
#         [0.6878, 0.7888, 0.8960]], requires_grad=True)
# 17번째 : Loss : 3.392882354091853e-05
# tensor([[0.1027, 0.2063, 0.2960],
#         [0.3948, 0.4995, 0.5937],
#         [0.6905, 0.7913, 0.8969]], requires_grad=True)
# 18번째 : Loss : 2.052480704151094e-05
# tensor([[0.1021, 0.2049, 0.2969],
#         [0.3959, 0.4996, 0.5951],
#         [0.6926, 0.7932, 0.8976]], requires_grad=True)
# 19번째 : Loss : 1.241622885572724e-05
# tensor([[0.1016, 0.2038, 0.2976],
#         [0.3968, 0.4997, 0.5962],
#         [0.6943, 0.7947, 0.8981]], requires_grad=True)
# 20번째 : Loss : 7.511082458222518e-06
# tensor([[0.1013, 0.2030, 0.2981],
#         [0.3975, 0.4998, 0.5971],
#         [0.6955, 0.7959, 0.8985]], requires_grad=True)
